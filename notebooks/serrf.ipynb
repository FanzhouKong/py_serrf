# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import os
import sys
sys.path.append('..')
import sklearn.neighbors._base
import sys
import seaborn as sns
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest
import src.serrf as srf
import concurrent.futures
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data, compound_list = srf.readin_template( 'mx 612255_longevity_males_lipidomics_ESIneg_processed 08-01-2024_reduced_for SERRF_transposed_SERRF Format.csv')

# %%
data_normalized,data_raw= srf.serrf_parallel(data, compound_list)
# Out:
# 100%|██████████| 1589/1589 [13:21<00:00,  1.98it/s]
# /Users/fanzhoukong/Documents/GitHub/Super_RT/notebooks/../toolsets/serrf.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_normalized.insert(0, 'sampleType', data['1_sampleType'])
# /Users/fanzhoukong/Documents/GitHub/Super_RT/notebooks/../toolsets/serrf.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_normalized.insert(1, 'time', data['2_time'])
# ...

# %%
srf.cv_plot(data_normalized, compound_list[5])

# %%
srf.cv_plot(data_raw, compound_list[5])

# %%
srf.pca_plot(data_normalized, compound_list)

# %%
srf.pca_plot(data_raw, compound_list)
